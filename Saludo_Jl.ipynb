# %% [markdown]
# <a href="https://colab.research.google.com/github/Matt-ELR/AED_Practica1.1/blob/feature-saludo/Saludo_Jl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
function saludo_personalizado(nombre::String)
    # Usamos $(nombre) para que Julia sepa dónde termina la variable
    println("¡Hola, $(nombre)! Bienvenido al repositorio de Julia.")
end

# Prueba la función
saludo_personalizado("Compañero")
# Out:
# ¡Hola, Compañero! Bienvenido al repositorio de Julia.
